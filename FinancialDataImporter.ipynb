# %%
from sqlalchemy import create_engine, text
import psycopg2
import pandas as pd
from datetime import datetime

# %%
engine = create_engine("postgresql://postgres:WjValpnjgoYyLCVqoPrZhiSbVwdbgbUh@roundhouse.proxy.rlwy.net:44826/railway")

gme = pd.read_csv('/Users/leotyler/Downloads/GME (1).csv')
nvda = pd.read_csv('/Users/leotyler/Downloads/NVDA (1).csv')
wing = pd.read_csv('/Users/leotyler/Downloads/WING (1).csv')
doge = pd.read_csv('/Users/leotyler/Downloads/Doge.csv')

# %%
for row in range(len(gme)):
    date_val = str(gme['Date'][row])
    open_val = float(gme['Open'][row])
    high = float(gme['High'][row])
    low = float(gme['Low'][row])
    close_val = float(gme['Close'][row])
    adj_close = float(gme['Adj Close'][row])
    volume = int(gme['Volume'][row])
    with engine.begin() as trans:
        trans.execute(text("""
                           INSERT INTO gme (date, open, high, low, close, adj_close, volume)
                           VALUES (:date, :open, :high, :low, :close, :adj_close, :volume)
                        """),
                {'date':date_val,
                 'open':open_val,
                 'high':high,
                 'low':low,
                 'close':close_val,
                 'adj_close':adj_close,
                 'volume':volume})

# %%
for row in range(len(nvda)):
    date_val = str(nvda['Date'][row])
    open_val = float(nvda['Open'][row])
    high = float(nvda['High'][row])
    low = float(nvda['Low'][row])
    close_val = float(nvda['Close'][row])
    adj_close = float(nvda['Adj Close'][row])
    volume = int(nvda['Volume'][row])
    with engine.begin() as trans:
        trans.execute(text("""
                           INSERT INTO nvda (date, open, high, low, close, adj_close, volume)
                           VALUES (:date, :open, :high, :low, :close, :adj_close, :volume)
                        """),
                {'date':date_val,
                 'open':open_val,
                 'high':high,
                 'low':low,
                 'close':close_val,
                 'adj_close':adj_close,
                 'volume':volume})

# %%
for row in range(len(wing)):
    date_val = str(wing['Date'][row])
    open_val = float(wing['Open'][row])
    high = float(wing['High'][row])
    low = float(wing['Low'][row])
    close_val = float(wing['Close'][row])
    adj_close = float(wing['Adj Close'][row])
    volume = int(wing['Volume'][row])
    with engine.begin() as trans:
        trans.execute(text("""
                           INSERT INTO wing (date, open, high, low, close, adj_close, volume)
                           VALUES (:date, :open, :high, :low, :close, :adj_close, :volume)
                        """),
                {'date':date_val,
                 'open':open_val,
                 'high':high,
                 'low':low,
                 'close':close_val,
                 'adj_close':adj_close,
                 'volume':volume})

# %%
for row in range(len(wing)):
    date_val = str(wing['Date'][row])
    print(date_val)
# Out:
# 2022-05-24
# 2022-05-25
# 2022-05-26
# 2022-05-27
# 2022-05-31
# 2022-06-01
# 2022-06-02
# 2022-06-03
# 2022-06-06
# 2022-06-07
# 2022-06-08
# 2022-06-09
# 2022-06-10
# 2022-06-13
# 2022-06-14
# 2022-06-15
# 2022-06-16
# 2022-06-17
# 2022-06-21
# 2022-06-22
# 2022-06-23
# 2022-06-24
# 2022-06-27
# 2022-06-28
# 2022-06-29
# 2022-06-30
# 2022-07-01
# 2022-07-05
# 2022-07-06
# 2022-07-07
# 2022-07-08
# 2022-07-11
# 2022-07-12
# 2022-07-13
# 2022-07-14
# 2022-07-15
# 2022-07-18
# 2022-07-19
# 2022-07-20
# 2022-07-21
# 2022-07-22
# 2022-07-25
# 2022-07-26
# 2022-07-27
# 2022-07-28
# 2022-07-29
# 2022-08-01
# 2022-08-02
# 2022-08-03
# 2022-08-04
# 2022-08-05
# 2022-08-08
# 2022-08-09
# 2022-08-10
# 2022-08-11
# 2022-08-12
# 2022-08-15
# 2022-08-16
# 2022-08-17
# 2022-08-18
# 2022-08-19
# 2022-08-22
# 2022-08-23
# 2022-08-24
# 2022-08-25
# 2022-08-26
# 2022-08-29
# 2022-08-30
# 2022-08-31
# 2022-09-01
# 2022-09-02
# 2022-09-06
# 2022-09-07
# 2022-09-08
# 2022-09-09
# 2022-09-12
# ...

# %%
for row in range(len(doge)):
    date = datetime.fromisoformat(doge['timeOpen'][row].rstrip('Z'))
    print(date)
    date2= date.date()
    date_val = date2.strftime('%Y-%m-%d')
    print(date_val)
    #date_val = doge['timeOpen'][row]
    open_val = float(doge['open'][row])
    high = float(doge['high'][row])
    low = float(doge['low'][row])
    close_val = float(doge['close'][row])
    marketcap = float(doge['marketCap'][row])
    volume = int(doge['volume'][row])
    with engine.begin() as trans:
        trans.execute(text("""
                           INSERT INTO dogecoin (date, open, high, low, close, volume, market_cap)
                           VALUES (:date, :open, :high, :low, :close, :volume, :market_cap)
                        """),
                {'date':date_val,
                 'open':open_val,
                 'high':high,
                 'low':low,
                 'close':close_val,
                 'market_cap':marketcap,
                 'volume':volume})
# Out:
# 2023-01-01 00:00:00
# 2023-01-01
# 2022-12-31 00:00:00
# 2022-12-31
# 2022-12-30 00:00:00
# 2022-12-30
# 2022-12-29 00:00:00
# 2022-12-29
# 2022-12-28 00:00:00
# 2022-12-28
# 2022-12-27 00:00:00
# 2022-12-27
# 2022-12-26 00:00:00
# 2022-12-26
# 2022-12-25 00:00:00
# 2022-12-25
# 2022-12-24 00:00:00
# 2022-12-24
# 2022-12-23 00:00:00
# 2022-12-23
# 2022-12-22 00:00:00
# 2022-12-22
# 2022-12-21 00:00:00
# 2022-12-21
# 2022-12-20 00:00:00
# 2022-12-20
# 2022-12-19 00:00:00
# 2022-12-19
# 2022-12-18 00:00:00
# 2022-12-18
# 2022-12-17 00:00:00
# 2022-12-17
# 2022-12-16 00:00:00
# 2022-12-16
# 2022-12-15 00:00:00
# 2022-12-15
# 2022-12-14 00:00:00
# 2022-12-14
# 2022-12-13 00:00:00
# 2022-12-13
# 2022-12-12 00:00:00
# 2022-12-12
# 2022-12-11 00:00:00
# 2022-12-11
# 2022-12-10 00:00:00
# 2022-12-10
# 2022-12-09 00:00:00
# 2022-12-09
# 2022-12-08 00:00:00
# 2022-12-08
# 2022-12-07 00:00:00
# 2022-12-07
# 2022-12-06 00:00:00
# 2022-12-06
# 2022-12-05 00:00:00
# 2022-12-05
# ...
